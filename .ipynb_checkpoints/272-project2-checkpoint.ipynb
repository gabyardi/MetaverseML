# %%
import pandas as pd
import numpy as np
import altair as alt
from collections import Counter
import NLP
from dataprep.clean import validate_country
import altair as alt
# instantiate one
import spacy 
nlp = spacy.load('en_core_web_sm')
#import geopy.geocoder
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from functools import partial
from tqdm import tqdm
import folium 
import pandas as pd
tqdm.pandas()
import re

import matplotlib.pyplot as plt
import seaborn as sns 
import string 
import nltk
import warnings
# %matplotlib inline

# %%
df = pd.read_csv('metaverse_tweets.csv')

# %% [markdown]
# # Preprocessing the Dataset

# %% [markdown]
# Sparese Columns: finding columns that are unpredictive columns

# %%
l = list(df.columns[df.nunique()/len(df) < 0.01])
df = df.drop(l, axis=1)

# %%
# from numpy import arange
# import altair as alt

# df = df[['user_followers', 'user_friends', 'user_favourites']]
# data = df.values
# X = data[:, :-1]
# y = data[:, -1]

# print(X.shape, y.shape)

# thresholds = arange(0.0, 0.55, 0.05)

# results = []
# for t in thresholds:
    
#     transform = VarianceThreshold(threshold=t)
    
#     X_sel = transform.fit_transform(X)
#     rows, cols = X_sel.shape
#     n_features = cols
#     print('Threshold=%.2f, Features=%d' % (t, n_features))
    
#     results.append(n_features)
    
# d2 = pd.DataFrame({'threshold': thresholds, 'n_features': results})
# alt.Chart(d2).mark_line().encode(
#     x='threshold',
#     y='n_features')

# %%
#Getting rid of duplicates 
df.drop_duplicates(inplace=True)

# %%
#remove pattern in the input text
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for word in r:
        input_txt = re.sub(word, "", input_txt)
    return input_txt

# %%
#Removing emoticons from the data using the re model and hard coding values 
def remove_emoji(string):
    if string == None:
        string = ""
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F" #emoticons
        u"\U0001F300-\U0001F5FF" #symbols & Pictographs
        u"\U0001F680-\U0001F6FF" #transport & map symbols
        u"\U0001F1E0-\U0001F1FF" #flags IOS
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE,
    )
    return emoji_pattern.sub(r"", string)

# %%
#remove twitter handles 
df['clean_tweet'] = np.vectorize(remove_pattern)(df['text'], "@[\w]*")
#remove special characters and numbers 
df['clean_tweet'] = df['clean_tweet'].str.replace("[^a-zA-Z#]", " ")
#remove https 
df['clean_tweet'] = df['clean_tweet'].str.replace("https\S+|www\S+https\S+", " ")
#Removing hashtags
df['clean_tweet'] = df['clean_tweet'].str.replace("#",  "")
#Remove short words
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))
#removes emojis
df['clean_tweet'] = df['clean_tweet'].map(lambda x: remove_emoji(x))
# lower case
df['clean_tweet'] = df['clean_tweet'].str.lower()
# Out:
# /var/folders/fc/4vw5bd5150scd_yn0b1lq5gw0000gn/T/ipykernel_7384/3673450202.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['clean_tweet'] = df['clean_tweet'].str.replace("[^a-zA-Z#]", " ")
# /var/folders/fc/4vw5bd5150scd_yn0b1lq5gw0000gn/T/ipykernel_7384/3673450202.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['clean_tweet'] = df['clean_tweet'].str.replace("https\S+|www\S+https\S+", " ")

# %%
#Tokenization pre-processing 
tokenized_tweet = df['clean_tweet'].apply(lambda x: x.split())

# %%
# stem the word -> narrow to a single common word
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda sentence: [stemmer.stem(word) for word in sentence])

#Combine into string 
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = " ".join(tokenized_tweet[i])
               
df['clean_tweet'] = tokenized_tweet

# %%
#!pip install TextBlob

# %%
from textblob import TextBlob

def polarity(text):
    return TextBlob(text).sentiment.polarity

df['polarity'] = df['text'].apply(polarity)

# %%
def sentiment(label):
    if label <= 0: return 0
    elif label > 0: return 1

df['sentiment'] = df['polarity'].apply(sentiment)

# %%
#Eliminate rows with na values and remove emojis
df = df.dropna()
# df_nona['user_description'] = df['user_description'].map(lambda x: remove_emoji(x))
df['user_name'] = df['user_name'].map(lambda x: remove_emoji(x))
df['text'] = df['text'].map(lambda x: remove_emoji(x))
# Out:
#                                     user_name         user_location  \
# 1                                       Duncs  Melbourne, Australia
# 5                                        Lyxo         Uyo,Akwa Ibom
# 8                                        Lyxo         Uyo,Akwa Ibom
# 10                                      Duncs  Melbourne, Australia
# 15                             NFTcrawler.eth              NFTverse
# ..                                        ...                   ...
# 994  MySmirkingPromotions hottest new cryptos                canada
# 996                           Scorpion Design                    UK
# 997                           Scorpion Design                    UK
# 998                           Scorpion Design                    UK
# 999                           Scorpion Design                    UK
#
#                                       user_description  \
# 1    NFT's + Crypto + Metaverse + Outdoors + Goodtimes
# 5    Anatomist||Man utd faithful || Music freak || ...
# 8    Anatomist||Man utd faithful || Music freak || ...
# 10   NFT's + Crypto + Metaverse + Outdoors + Goodtimes
# 15                                                #mww
# ..                                                 ...
# 994  Im going to slowly start populating the TG: ht...
# 996  Mathematical Physicist. Digital art, conceptua...
# 997  Mathematical Physicist. Digital art, conceptua...
# 998  Mathematical Physicist. Digital art, conceptua...
# 999  Mathematical Physicist. Digital art, conceptua...
#
#                   user_created  user_followers  user_friends  user_favourites  \
# 1    2012-11-28 01:47:19+00:00             745          1363             2583
# 5    2019-09-16 00:42:59+00:00             849            94            26422
# 8    2019-09-16 00:42:59+00:00             849            94            26422
# 10   2012-11-28 01:47:19+00:00             745          1363             2583
# 15   2009-07-04 13:44:10+00:00             193            97              347
# ..                         ...             ...           ...              ...
# 994  2021-03-08 02:23:13+00:00            2875          4846              431
# 996  2014-05-10 16:10:39+00:00            7860          7914             9994
# 997  2014-05-10 16:10:39+00:00            7860          7914             9994
# 998  2014-05-10 16:10:39+00:00            7860          7914             9994
# 999  2014-05-10 16:10:39+00:00            7860          7914             9994
#
#                           date  \
# 1    2022-02-27 23:59:33+00:00
# 5    2022-02-27 23:59:04+00:00
# 8    2022-02-27 23:58:46+00:00
# 10   2022-02-27 23:58:22+00:00
# 15   2022-02-27 23:56:32+00:00
# ..                         ...
# 994  2022-02-27 22:08:47+00:00
# 996  2022-02-27 22:08:42+00:00
# 997  2022-02-27 22:08:34+00:00
# 998  2022-02-27 22:08:18+00:00
# 999  2022-02-27 22:08:09+00:00
#
#                                                   text  \
# 1    Can't wait to hear this #Bapesclan \n\n#BapesM...
# 5    @supertobi64 #MiniKishu is the next BIG projec...
# 8    @PeeGee05 @MatrixETF @DEnergizer645 @anietieet...
# 10   Cant wait for #spacebapes \n\n#bapesclan #Meta...
# 15   @whitesandsgame @nftworldsNFT White Sands will...
# ..                                                 ...
# 994  PLS RETWEET\n  209 ADA\nhttps://t.co/4QNXjcap2...
# 996  Check out this new digital art that I uploaded...
# 997  Check out this new digital art that I uploaded...
# 998  Check out this new digital art that I uploaded...
# 999  Check out this new digital art that I uploaded...
#
#                                               hashtags              source  \
# 1        ['Bapesclan', 'BapesMetavestor', 'Metaverse']     Twitter Web App
# 5            ['MiniKishu', 'BSC', 'gaming', 'staking']  Twitter for iPhone
# 8                                 ['MiniKishu', 'BSC']  Twitter for iPhone
# 10   ['spacebapes', 'bapesclan', 'Metaverse', 'bape...     Twitter Web App
# 15                                       ['Metaverse']     Twitter Web App
# ..                                                 ...                 ...
# 994  ['NFTs', 'CNFTs', 'NFTCommmunity', 'Cardano', ...     Twitter Web App
# 996                                            ['art']     Twitter Web App
# 997                                            ['art']     Twitter Web App
# 998                                            ['art']     Twitter Web App
# 999                                            ['art']     Twitter Web App
#
#                                            clean_tweet  polarity  sentiment
# 1    wait hear thi bapesclan bapesmetavestor metave...  0.000000          0
# 5    minikishu next project ecosystem combin game w... -0.057386          0
# 8    minikishu next project ecosystem combin game w... -0.057386          0
# 10   cant wait spacebap bapesclan metavers bapesmet...  0.000000          0
# 15             white sand will miami metavers metavers  0.000000          0
# ..                                                 ...       ...        ...
# 994  retweet http qnxjcap rank nft cnft nftcommmun ... -0.800000          0
# 996  check thi digit that upload http fnjp http art...  0.068182          1
# 997  check thi digit that upload http fnjp http bet...  0.068182          1
# 998  check thi digit that upload http fnjp http pqj...  0.068182          1
# 999  check thi digit that upload http fnjp http zru...  0.068182          1
#
# [355 rows x 14 columns]

# %%
#Eliminate outliers
q_low = df["user_followers"].quantile(0.05)
q_hi  = df["user_followers"].quantile(0.95)

df = df[(df["user_followers"] < q_hi) & (df["user_followers"] > q_low)]

q_low = df["user_friends"].quantile(0.05)
q_hi  = df["user_friends"].quantile(0.95)

df = df[(df["user_friends"] < q_hi) & (df["user_friends"] > q_low)]
# Out:
#           user_name         user_location  \
# 1             Duncs  Melbourne, Australia
# 5              Lyxo         Uyo,Akwa Ibom
# 8              Lyxo         Uyo,Akwa Ibom
# 10            Duncs  Melbourne, Australia
# 15   NFTcrawler.eth              NFTverse
# ..              ...                   ...
# 983   star nft labs         United States
# 988   star nft labs         United States
# 989   BadBears.nft                Ireland
# 991   star nft labs         United States
# 993    Crypto Space       London, England
#
#                                       user_description  \
# 1    NFT's + Crypto + Metaverse + Outdoors + Goodtimes
# 5    Anatomist||Man utd faithful || Music freak || ...
# 8    Anatomist||Man utd faithful || Music freak || ...
# 10   NFT's + Crypto + Metaverse + Outdoors + Goodtimes
# 15                                                #mww
# ..                                                 ...
# 983  NFT STAR LABORATORIES . IT IS A TEAM OF 6 PEOP...
# 988  NFT STAR LABORATORIES . IT IS A TEAM OF 6 PEOP...
# 989  https://t.co/1Lnqlx57GY\n\nGoofball https://t....
# 991  NFT STAR LABORATORIES . IT IS A TEAM OF 6 PEOP...
# 993        Crypto hodler: buy the rumor, sell the news
#
#                   user_created  user_followers  user_friends  user_favourites  \
# 1    2012-11-28 01:47:19+00:00             745          1363             2583
# 5    2019-09-16 00:42:59+00:00             849            94            26422
# 8    2019-09-16 00:42:59+00:00             849            94            26422
# 10   2012-11-28 01:47:19+00:00             745          1363             2583
# 15   2009-07-04 13:44:10+00:00             193            97              347
# ..                         ...             ...           ...              ...
# 983  2021-10-27 18:30:33+00:00             385           639             1177
# 988  2021-10-27 18:30:33+00:00             385           639             1177
# 989  2013-04-14 13:41:39+00:00             127           194             1120
# 991  2021-10-27 18:30:33+00:00             385           639             1177
# 993  2021-09-09 18:57:45+00:00              43           125              131
#
#                           date  \
# 1    2022-02-27 23:59:33+00:00
# 5    2022-02-27 23:59:04+00:00
# 8    2022-02-27 23:58:46+00:00
# 10   2022-02-27 23:58:22+00:00
# 15   2022-02-27 23:56:32+00:00
# ..                         ...
# 983  2022-02-27 22:09:27+00:00
# 988  2022-02-27 22:09:17+00:00
# 989  2022-02-27 22:09:17+00:00
# 991  2022-02-27 22:09:09+00:00
# 993  2022-02-27 22:08:54+00:00
#
#                                                   text  \
# 1    Can't wait to hear this #Bapesclan \n\n#BapesM...
# 5    @supertobi64 #MiniKishu is the next BIG projec...
# 8    @PeeGee05 @MatrixETF @DEnergizer645 @anietieet...
# 10   Cant wait for #spacebapes \n\n#bapesclan #Meta...
# 15   @whitesandsgame @nftworldsNFT White Sands will...
# ..                                                 ...
# 983  Check out this item on OpenSea https://t.co/Gc...
# 988  Check out this item on OpenSea https://t.co/Eh...
# 989  @savage_nftz @badbearsmsk 11 cubs for the #Met...
# 991  Check out this item on OpenSea https://t.co/kB...
# 993  Next #cryptocurrency to explode is $blok @blok...
#
#                                               hashtags               source  \
# 1        ['Bapesclan', 'BapesMetavestor', 'Metaverse']      Twitter Web App
# 5            ['MiniKishu', 'BSC', 'gaming', 'staking']   Twitter for iPhone
# 8                                 ['MiniKishu', 'BSC']   Twitter for iPhone
# 10   ['spacebapes', 'bapesclan', 'Metaverse', 'bape...      Twitter Web App
# 15                                       ['Metaverse']      Twitter Web App
# ..                                                 ...                  ...
# 983  ['nft', 'NFTs', 'NFTGiveaway', 'NFTCommunity',...      Twitter Web App
# 988  ['nft', 'NFTs', 'NFTGiveaway', 'NFTCommunity',...      Twitter Web App
# 989                                      ['Metaverse']  Twitter for Android
# 991  ['nft', 'NFTs', 'NFTGiveaway', 'NFTCommunity',...      Twitter Web App
# 993                      ['cryptocurrency', 'bitcoin']      Twitter Web App
#
#                                            clean_tweet  polarity  sentiment
# 1    wait hear thi bapesclan bapesmetavestor metave...  0.000000          0
# 5    minikishu next project ecosystem combin game w... -0.057386          0
# 8    minikishu next project ecosystem combin game w... -0.057386          0
# 10   cant wait spacebap bapesclan metavers bapesmet...  0.000000          0
# 15             white sand will miami metavers metavers  0.000000          0
# ..                                                 ...       ...        ...
# 983  check thi item opensea http gcrzimcmkj nft nft...  0.000000          0
# 988  check thi item opensea http cnblb nft nftgivea...  0.000000          0
# 989                          cub metavers http cjcsibt  0.000000          0
# 991  check thi item opensea http kbtj nft nftgiveaw...  0.000000          0
# 993  next cryptocurr explod blok mani reason bullis...  0.250000          1
#
# [271 rows x 14 columns]

# %% [markdown]
# ## Exploratory Analysis

# %%
#!pip install wordcloud

# %%
#frequent words positive 
words = " ".join([sentence for sentence in df['clean_tweet'][df['sentiment']== 1]])

from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height=500, random_state=42, max_font_size=100).generate(words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#frequent words negative
words = " ".join([sentence for sentence in df['clean_tweet'][df['sentiment']==0]])

from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height=500, random_state=42, max_font_size=100).generate(words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Get most common words in tweets and the count
str_tweet = df["clean_tweet"].str.cat(sep = ' ')
from collections import Counter
nlp = spacy.load('en_core_web_sm')
doc = nlp(str_tweet)
# all tokens that arent stop words or punctuations
words = [token.text
         for token in doc
         if not token.is_stop and not token.is_punct]

# 25 most common tokens
word_freq = Counter(words)
top_common_words = word_freq.most_common(25)

top_words = [word for word, count in top_common_words]

# %%
top_common_words
# Out:
# [('metavers', 292),
#  ('http', 281),
#  ('nft', 118),
#  ('game', 109),
#  ('nftcommun', 104),
#  ('thi', 90),
#  ('nftcollector', 90),
#  ('nftcollect', 68),
#  ('nftartist', 68),
#  ('nftdrop', 62),
#  ('project', 61),
#  ('check', 61),
#  ('openseanft', 61),
#  ('nftgiveaway', 58),
#  ('opensea', 56),
#  ('nftproject', 56),
#  ('stake', 55),
#  ('ethnft', 55),
#  ('ethereumnft', 54),
#  ('item', 53),
#  ('collector', 53),
#  ('boredap', 53),
#  ('boredapeyc', 53),
#  ('mutantapeyachtclub', 53),
#  ('xapestrilog', 53)]

# %%
#Graph of the distribution of word count in tweets
df["word_count"] = df["clean_tweet"].str.split().str.len()
alt.Chart(df).mark_line().encode(
    x='word_count',
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
#Distribution of user_followers
alt.Chart(df).mark_line().encode(
    x='user_followers',
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
#Distribution of user_followers
alt.Chart(df).mark_bar().encode(
    x='source',
    y='count()'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Split Data

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(df['clean_tweet'])

# %%
bow[0]
# Out:
# <1x301 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
#Data Leakage Problem
from sklearn.preprocessing import MaxAbsScaler 

scaler = MaxAbsScaler()
# !!! fitting before the split
bow = scaler.fit_transform(bow)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(bow, df['sentiment'], random_state = 1, test_size = 0.33)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report

#Training
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Testing
pred = model.predict(x_test)
f1_score = f1_score(y_test, pred)
print("f1_score : {:.2f}%".format(f1_score *100))
# Out:
# f1_score : 67.80%

# %%
a = accuracy_score(y_test, pred)
print("Test accuracy: {:.2f}%".format(a*100))
# Out:
# Test accuracy: 78.89%

# %%
#confusion_matrix(y_test, pred)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        62
#            1       0.65      0.71      0.68        28
#
#     accuracy                           0.79        90
#    macro avg       0.75      0.77      0.76        90
# weighted avg       0.80      0.79      0.79        90
